# %% [markdown]
# <span style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">An Exception was encountered at '<a href="#papermill-error-cell">In [12]</a>'.</span>

# %%
import pandas as pd  
import numpy as np  
import os  
import sys  
import collections
from itertools import chain
import json
from IPython.display import display, HTML
import csv
import glob
import h5py
import re

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', 0)
pd.options.display.float_format = lambda x: '{:,.2f}'.format(x) if x > 1 else '{:,.2%}'.format(x)

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
top_metrics_file = 'top_metrics_for_tbl.csv'
input_h5_file = ''
input_base_file_name = ''

# %%
# Parameters
top_metrics_file = (
    "/home/gat.krieger/proj/VariantCalling/ugvc/reports/top_metrics_for_tbl.csv"
)
input_h5_file = "/data/report_fixes/ssqc_from_sorter/026532-Lb_1866-Z0058-CATCTCAGTGCAATGAT.aggregated_metrics.h5"
input_base_file_name = "026532-Lb_1866-Z0058-CATCTCAGTGCAATGAT"

# %%
if not os.path.isfile(top_metrics_file):
    raise ValueError(f"Input {top_metrics_file} does not exist")

# %%
   
dict_features = {row[0] : row[1] for _, row in pd.read_csv(top_metrics_file).iterrows()}
df_features = pd.read_csv(top_metrics_file)
list_metrics = list(set(df_features['metric'] ))

# %%
# get Keys within the H5 file
f = h5py.File(input_h5_file, 'r')
list_keys = list(f.keys())
hist_list_keys =  [i for i in list_keys if i.startswith('histogram_')]
tbl_list_keys = pd.DataFrame(list(set(list_keys) - set(hist_list_keys)))
tbl_list_keys.columns = ['metric']
del(list_keys)

# create table merging top required metrics to display and input provided
# ....................
tbl_top_values = pd.merge(df_features,tbl_list_keys,on='metric',how='inner')

# %%
HTML("<b>"+""+"</b>")
HTML("<hr/>")
HTML("<h2 style=\"font-size:20px;\">"+"Input parameters"+"</h2>")
HTML("<hr/>")
HTML("<b>"+""+"</b>")
# Out:
# <b></b>
# <hr/>
# <h2 style="font-size:20px;">Input parameters</h2>
# <hr/>
# <b></b>

# %%
to_print_sample_info = pd.DataFrame(
        data = {
            'value' : [input_base_file_name, str(input_h5_file)]
        },
        index = ['Sample name', 'h5 file'])

to_print_sample_info['value'] = to_print_sample_info['value'].str.wrap(100)
def wrap_df_text(df):
    return display(HTML(df.to_html().replace("\\n","<br>")))

wrap_df_text(to_print_sample_info.style.set_properties(**{'text-align': 'left'}))
# Out:
# <style type="text/css">
# #T_4cd76_row0_col0, #T_4cd76_row1_col0 {
#   text-align: left;
# }
# </style>
# <table id="T_4cd76">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4cd76_level0_col0" class="col_heading level0 col0" >value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4cd76_level0_row0" class="row_heading level0 row0" >Sample name</th>
#       <td id="T_4cd76_row0_col0" class="data row0 col0" >026532-Lb_1866-Z0058-CATCTCAGTGCAATGAT</td>
#     </tr>
#     <tr>
#       <th id="T_4cd76_level0_row1" class="row_heading level0 row1" >h5 file</th>
#       <td id="T_4cd76_row1_col0" class="data row1 col0" >/data/report_fixes/ssqc_from_sorter/026532-Lb_1866-Z0058-CATCTCAGTGCAATGAT.aggregated_metrics.h5</td>
#     </tr>
#   </tbody>
# </table>

# %%
HTML("<b>"+""+"</b>")
HTML("<hr/>")
HTML("<h2 style=\"font-size:20px;\">"+"Summary View: Main Metrics"+"</h2>")
HTML("<hr/>")
HTML("<b>"+""+"</b>")
# Out:
# <b></b>
# <hr/>
# <h2 style="font-size:20px;">Summary View: Main Metrics</h2>
# <hr/>
# <b></b>

# %%
exisiting_keys
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 exisiting_keys
#
# NameError: name 'exisiting_keys' is not defined

# %% [markdown]
# <span id="papermill-error-cell" style="color:red; font-family:Helvetica Neue, Helvetica, Arial, sans-serif; font-size:2em;">Execution using papermill encountered an exception here and stopped:</span>

# %%
with pd.HDFStore(input_h5_file, mode = 'r') as store:
    exisiting_keys = store.keys()

for key in exisiting_keys:
    HTML("<br>"+"<br>"+"<b>"+"Metric type: " + key.replace('/','') + "</b>"+"<br>")
    df_key = pd.read_hdf(input_h5_file, key)
    df_key = df_key.T
    df_key.columns = ["value"]
    display(df_key)
# Out:
# <br><br><b>Metric type: AlignmentSummaryMetrics</b><br>
#                                      value
# PCT_PF_ALIGNED           98.49
# PCT_PF_HQ_ALIGNED        91.68
# PF_MISMATCH_RATE         38.00%
# PF_INDEL_RATE            44.00%
# MEAN_READ_LENGTH         260.07
# MEDIAN_READ_LENGTH       284.00
# MEAN_ALIGNED_READ_LENGTH 260.39
# MQ_GTE_1                 114,614,928.00
# MQ_GTE_10                113,380,377.00
# MQ_GTE_20                112,006,589.00
# MQ_GTE_30                111,216,867.00
# PCT_CHIMERAS             1.15
# PF_ALIGNED_READS         122,010,009.00
# PF_ALIGNED_BASES         31,297,561,923.00
# PF_HQ_ALIGNED_READS      112,006,589.00
# PF_HQ_ALIGNED_BASES      29,135,492,280.00
# <br><br><b>Metric type: DuplicationMetrics</b><br>
#                      value
# PERCENT_DUPLICATION 7.72
# <br><br><b>Metric type: QualityYieldMetricsFlow</b><br>
#                              value
# PF_READS         122,191,864.00
# PCT_PF_Q20_BASES 85.21
# MEAN_QUALITY     36.63
# NON_PF_READS     0.00%
# PCT_NON_PF_READS 0.00%
# TOTAL_READS      122,191,864.00
# TOTAL_BASES      31,777,881,341.00
# PF_BASES         31,777,881,341.00
# <br><br><b>Metric type: RawWgsMetrics</b><br>
#                              value
# MEAN_COVERAGE               9.98
# MEDIAN_COVERAGE             10.00
# PCT_1X                      99.52
# PCT_5X                      94.52
# PCT_10X                     51.03
# PCT_20X                     1.03
# PCT_50X                     11.00%
# PCT_100X                    4.00%
# PCT_500X                    1.00%
# PCT_1000X                   0.00%
# FOLD_80_BASE_PENALTY_AT_30X 1.43
# FOLD_90_BASE_PENALTY_AT_30X 1.67
# FOLD_95_BASE_PENALTY_AT_30X 2.50
# <br><br><b>Metric type: stats_coverage</b><br>
#                                                           value
#
# Genome         percentile_5                             3.81
#                percentile_10                            5.00
#                median_coverage                          9.09
#                median_coverage_normalized               100.00%
#                percent_larger_than_05_of_genome_median  94.52
#                percent_larger_than_025_of_genome_median 98.43
#                percent_over_or_equal_to_10x             51.03
#                percent_over_or_equal_to_20x             1.03
# Exome          percentile_5                             4.24
#                percentile_10                            5.28
#                median_coverage                          9.29
#                median_coverage_normalized               1.02
#                percent_larger_than_05_of_genome_median  95.98
#                percent_larger_than_025_of_genome_median 99.30
#                percent_over_or_equal_to_10x             53.49
#                percent_over_or_equal_to_20x             67.82%
# ACMG59         percentile_5                             5.76
#                percentile_10                            6.60
#                median_coverage                          10.24
#                median_coverage_normalized               1.13
#                percent_larger_than_05_of_genome_median  98.44
#                percent_larger_than_025_of_genome_median 99.14
#                percent_over_or_equal_to_10x             67.17
#                percent_over_or_equal_to_20x             1.31
# Exon 1         percentile_5                             3.59
#                percentile_10                            4.80
#                median_coverage                          8.95
#                median_coverage_normalized               98.50%
#                percent_larger_than_05_of_genome_median  93.81
#                percent_larger_than_025_of_genome_median 98.14
#                percent_over_or_equal_to_10x             49.44
#                percent_over_or_equal_to_20x             77.64%
# Exon >1        percentile_5                             4.19
#                percentile_10                            5.24
#                median_coverage                          9.21
#                median_coverage_normalized               1.01
#                percent_larger_than_05_of_genome_median  95.82
#                percent_larger_than_025_of_genome_median 99.28
#                percent_over_or_equal_to_10x             52.48
#                percent_over_or_equal_to_20x             63.60%
# GC 10-20       percentile_5                             21.48%
#                percentile_10                            1.81
#                median_coverage                          7.25
#                median_coverage_normalized               79.80%
#                percent_larger_than_05_of_genome_median  79.87
#                percent_larger_than_025_of_genome_median 89.41
#                percent_over_or_equal_to_10x             32.17
#                percent_over_or_equal_to_20x             95.28%
# GC 20-30       percentile_5                             3.35
#                percentile_10                            4.51
#                median_coverage                          8.68
#                median_coverage_normalized               95.53%
#                percent_larger_than_05_of_genome_median  92.81
#                percent_larger_than_025_of_genome_median 98.05
#                percent_over_or_equal_to_10x             46.30
#                percent_over_or_equal_to_20x             1.34
# GC 30-40       percentile_5                             3.45
#                percentile_10                            4.77
#                median_coverage                          9.12
#                median_coverage_normalized               1.00
#                percent_larger_than_05_of_genome_median  93.49
#                percent_larger_than_025_of_genome_median 97.76
#                percent_over_or_equal_to_10x             51.34
#                percent_over_or_equal_to_20x             2.35
# GC 40-50       percentile_5                             3.99
#                percentile_10                            5.12
#                median_coverage                          9.31
#                median_coverage_normalized               1.02
#                percent_larger_than_05_of_genome_median  94.97
#                percent_larger_than_025_of_genome_median 98.67
#                percent_over_or_equal_to_10x             53.56
#                percent_over_or_equal_to_20x             1.71
# GC 50-60       percentile_5                             4.04
#                percentile_10                            5.13
#                median_coverage                          9.25
#                median_coverage_normalized               1.02
#                percent_larger_than_05_of_genome_median  95.17
#                percent_larger_than_025_of_genome_median 98.92
#                percent_over_or_equal_to_10x             52.93
#                percent_over_or_equal_to_20x             1.32
# GC 60-70       percentile_5                             3.62
#                percentile_10                            4.88
#                median_coverage                          9.12
#                median_coverage_normalized               1.00
#                percent_larger_than_05_of_genome_median  93.97
#                percent_larger_than_025_of_genome_median 98.24
#                percent_over_or_equal_to_10x             51.36
#                percent_over_or_equal_to_20x             1.24
# GC 70-80       percentile_5                             1.26
#                percentile_10                            3.08
#                median_coverage                          8.14
#                median_coverage_normalized               89.55%
#                percent_larger_than_05_of_genome_median  86.11
#                percent_larger_than_025_of_genome_median 93.40
#                percent_over_or_equal_to_10x             40.56
#                percent_over_or_equal_to_20x             1.20
# GC 80-90       percentile_5                             0.00%
#                percentile_10                            44.30%
#                median_coverage                          5.89
#                median_coverage_normalized               64.85%
#                percent_larger_than_05_of_genome_median  65.17
#                percent_larger_than_025_of_genome_median 78.74
#                percent_over_or_equal_to_10x             22.42
#                percent_over_or_equal_to_20x             52.79%
# GC 90-100      percentile_5                             0.00%
#                percentile_10                            0.00%
#                median_coverage                          22.26%
#                median_coverage_normalized               2.45%
#                percent_larger_than_05_of_genome_median  5.37
#                percent_larger_than_025_of_genome_median 16.96
#                percent_over_or_equal_to_10x             73.08%
#                percent_over_or_equal_to_20x             0.00%
# Unique         percentile_5                             3.89
#                percentile_10                            5.02
#                median_coverage                          9.13
#                median_coverage_normalized               1.00
#                percent_larger_than_05_of_genome_median  94.71
#                percent_larger_than_025_of_genome_median 98.71
#                percent_over_or_equal_to_10x             51.49
#                percent_over_or_equal_to_20x             1.39
# Non-unique     percentile_5                             30.54%
#                percentile_10                            1.82
#                median_coverage                          9.05
#                median_coverage_normalized               99.60%
#                percent_larger_than_05_of_genome_median  82.26
#                percent_larger_than_025_of_genome_median 89.43
#                percent_over_or_equal_to_10x             50.41
#                percent_over_or_equal_to_20x             8.22
# DNA repeats    percentile_5                             3.99
#                percentile_10                            5.02
#                median_coverage                          8.98
#                median_coverage_normalized               98.75%
#                percent_larger_than_05_of_genome_median  94.98
#                percent_larger_than_025_of_genome_median 99.03
#                percent_over_or_equal_to_10x             49.70
#                percent_over_or_equal_to_20x             1.03
# LINE           percentile_5                             4.06
#                percentile_10                            5.15
#                median_coverage                          9.31
#                median_coverage_normalized               1.02
#                percent_larger_than_05_of_genome_median  95.24
#                percent_larger_than_025_of_genome_median 98.91
#                percent_over_or_equal_to_10x             53.57
#                percent_over_or_equal_to_20x             1.74
# LTR            percentile_5                             4.14
#                percentile_10                            5.26
#                median_coverage                          9.45
#                median_coverage_normalized               1.04
#                percent_larger_than_05_of_genome_median  95.56
#                percent_larger_than_025_of_genome_median 98.96
#                percent_over_or_equal_to_10x             55.12
#                percent_over_or_equal_to_20x             1.90
# Low complexity percentile_5                             2.60
#                percentile_10                            4.08
#                median_coverage                          8.88
#                median_coverage_normalized               97.68%
#                percent_larger_than_05_of_genome_median  90.42
#                percent_larger_than_025_of_genome_median 96.32
#                percent_over_or_equal_to_10x             48.78
#                percent_over_or_equal_to_20x             2.74
# SINE           percentile_5                             3.56
#                percentile_10                            4.70
#                median_coverage                          8.83
#                median_coverage_normalized               97.17%
#                percent_larger_than_05_of_genome_median  93.64
#                percent_larger_than_025_of_genome_median 98.42
#                percent_over_or_equal_to_10x             48.00
#                percent_over_or_equal_to_20x             1.00
# Alu only       percentile_5                             3.38
#                percentile_10                            4.54
#                median_coverage                          8.71
#                median_coverage_normalized               95.80%
#                percent_larger_than_05_of_genome_median  92.91
#                percent_larger_than_025_of_genome_median 98.15
#                percent_over_or_equal_to_10x             46.55
#                percent_over_or_equal_to_20x             1.08
# Satelite       percentile_5                             0.00%
#                percentile_10                            25.62%
#                median_coverage                          7.83
#                median_coverage_normalized               86.11%
#                percent_larger_than_05_of_genome_median  67.66
#                percent_larger_than_025_of_genome_median 78.28
#                percent_over_or_equal_to_10x             45.20
#                percent_over_or_equal_to_20x             19.16
# Simple repeat  percentile_5                             1.62%
#                percentile_10                            1.66
#                median_coverage                          7.53
#                median_coverage_normalized               82.87%
#                percent_larger_than_05_of_genome_median  79.78
#                percent_larger_than_025_of_genome_median 88.95
#                percent_over_or_equal_to_10x             36.03
#                percent_over_or_equal_to_20x             1.62

# %%
tbl_top_values
# Out:
#                              key                   metric
# 0   TOTAL_READS                   AlignmentSummaryMetrics
# 1   PCT_PF_READS                  AlignmentSummaryMetrics
# 2   PCT_PF_READS_ALIGNED          AlignmentSummaryMetrics
# 3   MEAN_READ_LENGTH              AlignmentSummaryMetrics
# 4   MEAN_ALIGNED_READ_LENGTH      AlignmentSummaryMetrics
# 5   PF_INDEL_RATE                 AlignmentSummaryMetrics
# 6   PF_MISMATCH_RATE              AlignmentSummaryMetrics
# 7   PF_BASES                      QualityYieldMetricsFlow
# 8   PF_Q30_BASES                  QualityYieldMetricsFlow
# 9   MEAN_COVERAGE                 RawWgsMetrics
# 10  FOLD_90_BASE_PENALTY          RawWgsMetrics
# 11  PCT_20X                       RawWgsMetrics
# 12  Genome___percentile_5         stats_coverage
# 13  Exome (WG)___percentile_5     stats_coverage
# 14  Simple repeat___percentile_5  stats_coverage
# 15  PERCENT_DUPLICATION           DuplicationMetrics

# %%
# separator = '___'
i_value= np.nan 
to_print = pd.DataFrame()

tbl_top = pd.DataFrame()

tbl_top_metrics = tbl_top_values['metric'].unique().tolist()

for temp_metric in tbl_top_metrics:
    top_metric_slash = "/" + temp_metric
    if temp_metric not in exisiting_keys:
        continue
    print(temp_metric)
    list_top_tbl = sub_top_tbl = pd.DataFrame()
    sub_top_tbl =  tbl_top_values[tbl_top_values['metric'] == temp_metric]
    df_h5_tbl = pd.read_hdf(input_h5_file, top_metric_slash).T
    df_h5_tbl = df_h5_tbl.reset_index()
    display(sub_top_tbl)
    break
    # stats_coverage is a multiindex dataframe    
    if (temp_metric.startswith('stats') ):
        df_h5_tbl['metric'] = df_h5_tbl['level_0'] + separator + df_h5_tbl['level_1']
        df_h5_tbl = df_h5_tbl.drop(columns=['level_0','level_1']).copy()
        df_h5_tbl.columns = ['value','key']
        df_h5_tbl = df_h5_tbl[['key', 'value']]        
        list_top_tbl = pd.merge(df_h5_tbl, sub_top_tbl ,on='key',how='inner')
        to_print = pd.concat((to_print,list_top_tbl))
    else:
        df_h5_tbl.columns = ['key','value']    
        list_top_tbl = pd.merge(df_h5_tbl, sub_top_tbl ,on='key',how='inner')
        to_print = pd.concat((to_print, list_top_tbl))
    display(to_print)   

if type(to_print.loc[to_print.key == 'PCT_PF_READS', 'value'].values[0]) is int:
    to_print.loc[to_print.key == 'PCT_PF_READS', 'value'] = '100%'

to_print.index = to_print['key']
display(to_print['value'].to_frame())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_73473/3549473387.py in ?()
# ---> 34 # separator = '___'
#      35 i_value= np.nan
#      36 to_print = pd.DataFrame()
#      37
#
# ~/miniconda3/envs/genomics.py3/lib/python3.8/site-packages/pandas/core/generic.py in ?(self, name)
#    5898             and name not in self._accessors
#    5899             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'key'

# %%
top_metric_slash
pd.read_hdf(input_h5_file, top_metric_slash).T
# Out:
# '/DuplicationMetrics'
#                        0
# PERCENT_DUPLICATION 7.72

# %%
exisiting_keys
# Out:
# ['/AlignmentSummaryMetrics',
#  '/DuplicationMetrics',
#  '/QualityYieldMetricsFlow',
#  '/RawWgsMetrics',
#  '/stats_coverage']

# %%
HTML("<b>"+""+"</b>")
HTML("<hr/>")
HTML("<h2 style=\"font-size:20px;\">"+"Detailed View: All Metrics"+"</h2>")
HTML("<hr/>")
HTML("<b>"+""+"</b>")

# %%
to_print = pd.DataFrame()
sorted_keys  = tbl_list_keys['metric'].sort_values()

for tbl_key in sorted_keys:
    
    HTML("<br>"+"<br>"+"<b>"+"Metric type: "+tbl_key+"</b>"+"<br>")
    df_h5_tbl = pd.read_hdf(input_h5_file, tbl_key).T
    df_h5_tbl = df_h5_tbl.reset_index()
    

    if (tbl_key.startswith('stats') ):
        df_h5_tbl['metric'] = df_h5_tbl['level_0'] + separator + df_h5_tbl['level_1']
        df_h5_tbl = df_h5_tbl.drop(columns=['level_0','level_1']).copy()
        df_h5_tbl.columns = ['value','key']
        to_print = df_h5_tbl[['key', 'value']]        

    else:
        to_print = df_h5_tbl
        to_print.columns = ['key','value'] 
        
    to_print.index = to_print['key']
    display(to_print['value'].to_frame())
